# %% [markdown]
# # Analysis of Airbnb listings in London (Work-in-progress)
#
# This notebook will take a look at Airbnb listings in London. I spent three exciting years here while completing my undergrad at the London School of Economics. London holds many fond memories for me!
#
# We will focus on visualisations, using some new techniques of data & analysis that I've learnt on the job. First, we shall perform discovery and analysis on jupyter. Next, we deploy this in a dashboard using Bokeh!
#
# I've always enjoyed visualising data, and building things that users can interact with. Hope you find this useful!
#
# Acknowledgements:
# - https://www.kaggle.com/erikbruin/airbnb-the-amsterdam-story-with-interactive-maps
# - https://github.com/rweng18/bokeh_map
#
# Data source: http://insideairbnb.com/london/

# %% [markdown]
# ## 1) Import packages and data

# %%
import pandas as pd
import os
import gzip #to unzip .gzip files # https://stackoverflow.com/a/50115679

# %%
pd.set_option('display.max_columns', None) #set full rows

# %%
this_cwd = os.getcwd()
raw_data_folder = r"/DATA/"
raw_data_path = this_cwd  + raw_data_folder
for datafile in os.listdir(raw_data_path):
    print(datafile)
# Out:
# calendar.csv.gz
# listings.csv
# listings.csv.gz
# neighbourhoods.csv
# neighbourhoods.geojson
# reviews.csv
# reviews.csv.gz

# %% [markdown]
# Descriptions of data (from https://www.kaggle.com/erikbruin/airbnb-the-amsterdam-story-with-interactive-maps)
#
# - *calendar.csv.gz*: The calendar has 365 records for each listing. It specifies the whether the listing is available on a particular day (365 days ahead), and the price on that day.
# - *listings.csv*: A listing is basically an advertisement. This file holds the most useful variables that can be used visualizations.
# - *listings.csv.gz*: This file holds the same variables as the listing file plus 80 additional variables.
# - *neighbourhoods.csx*: Simple file with the names of the neighbouhoods
# - *reviews.csv*: This is a simple file that can be used to count the number of reviews by listing (for a specific period).
# - *reviews.csv.gz*: This file holds the full details of all reviews, and can also be used for instance for text mining.
# - *neighbourhoods.geojson*: This is the shape file that can be used in conjunction with interactive maps (such as Leaflet for R of the Python folium package).

# %%
temp1 = pd.read_csv(raw_data_path + '/listings.csv')
temp1.head()
# Out:
#       id                                               name  host_id  \
# 0  11551         Arty and Bright London Apartment in Zone 2    43039
# 1  13913                Holiday London DB Room Let-on going    54730
# 2  15400                Bright Chelsea  Apartment. Chelsea!    60302
# 3  17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1    67564
# 4  17506  Boutique Chelsea/Fulham Double bed 5-star ensuite    67915
#
#    host_name  neighbourhood_group           neighbourhood  latitude  \
# 0    Adriano                  NaN                 Lambeth  51.46225
# 1      Alina                  NaN               Islington  51.56802
# 2   Philippa                  NaN  Kensington and Chelsea  51.48796
# 3        Liz                  NaN             Westminster  51.52195
# 4  Charlotte                  NaN  Hammersmith and Fulham  51.47935
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -0.11732  Entire home/apt     88               2                188
# 1   -0.11121     Private room     65               1                 20
# 2   -0.16898  Entire home/apt    100              10                 88
# 3   -0.14094  Entire home/apt    300               3                 42
# 4   -0.19743     Private room    150               3                  0
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2020-01-24               1.56                               2
# 1  2019-11-25               0.17                               2
# 2  2019-09-23               0.71                               1
# 3  2019-11-02               0.39                              15
# 4         NaN                NaN                               2
#
#    availability_365
# 0               332
# 1               356
# 2               185
# 3               230
# 4               364

# %%
df_listings = pd.read_csv(raw_data_path + "listings.csv")
df_listings.head()
# Out:
#       id                                               name  host_id  \
# 0  11551         Arty and Bright London Apartment in Zone 2    43039
# 1  13913                Holiday London DB Room Let-on going    54730
# 2  15400                Bright Chelsea  Apartment. Chelsea!    60302
# 3  17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1    67564
# 4  17506  Boutique Chelsea/Fulham Double bed 5-star ensuite    67915
#
#    host_name  neighbourhood_group           neighbourhood  latitude  \
# 0    Adriano                  NaN                 Lambeth  51.46225
# 1      Alina                  NaN               Islington  51.56802
# 2   Philippa                  NaN  Kensington and Chelsea  51.48796
# 3        Liz                  NaN             Westminster  51.52195
# 4  Charlotte                  NaN  Hammersmith and Fulham  51.47935
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -0.11732  Entire home/apt     88               2                188
# 1   -0.11121     Private room     65               1                 20
# 2   -0.16898  Entire home/apt    100              10                 88
# 3   -0.14094  Entire home/apt    300               3                 42
# 4   -0.19743     Private room    150               3                  0
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2020-01-24               1.56                               2
# 1  2019-11-25               0.17                               2
# 2  2019-09-23               0.71                               1
# 3  2019-11-02               0.39                              15
# 4         NaN                NaN                               2
#
#    availability_365
# 0               332
# 1               356
# 2               185
# 3               230
# 4               364

# %%
df_listings.shape
# Out:
# (87571, 16)

# %%
with gzip.open(raw_data_path + 'listings.csv.gz') as f:

    df_listings_details = pd.read_csv(f)
# Out:
# D:\PYTHON_ENVIRONMENTS\AIRBNB\envs_airbnb\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (61,62,94,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_listings_details.head(10)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11551  https://www.airbnb.com/rooms/11551  20200216042433   2020-02-16
# 1  13913  https://www.airbnb.com/rooms/13913  20200216042433   2020-02-16
# 2  15400  https://www.airbnb.com/rooms/15400  20200216042433   2020-02-16
# 3  17402  https://www.airbnb.com/rooms/17402  20200216042433   2020-02-16
# 4  17506  https://www.airbnb.com/rooms/17506  20200216042433   2020-02-16
# 5  25023  https://www.airbnb.com/rooms/25023  20200216042433   2020-02-17
# 6  25123  https://www.airbnb.com/rooms/25123  20200216042433   2020-02-17
# 7  33332  https://www.airbnb.com/rooms/33332  20200216042433   2020-02-17
# 8  34825  https://www.airbnb.com/rooms/34825  20200216042433   2020-02-16
# 9  36299  https://www.airbnb.com/rooms/36299  20200216042433   2020-02-17
#
#                                                 name  \
# 0         Arty and Bright London Apartment in Zone 2
# 1                Holiday London DB Room Let-on going
# 2                Bright Chelsea  Apartment. Chelsea!
# 3              Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 4  Boutique Chelsea/Fulham Double bed 5-star ensuite
# 5      All-comforts 2-bed flat near Wimbledon tennis
# 6                  Clean big Room in London (Room 1)
# 7     Beautiful Ensuite Richmond-upon-Thames borough
# 8                   Zone 1, Dbl Room, Central London
# 9                Kew Gardens 3BR house in cul-de-sac
#
#                                              summary  \
# 0  Unlike most rental apartments out there my fla...
# 1  My bright double bedroom with a large window h...
# 2  Lots of windows and light.  St Luke's Gardens ...
# 3  You'll have a wonderful stay in this superb mo...
# 4  Enjoy a chic stay in this elegant but fully mo...
# 5  Large, all comforts, 2-bed flat; first floor; ...
# 6  Big room with double bed/ clean sheets/ clean ...
# 7  Walking distance to Twickenham Stadium, 35 min...
# 8  Bright, large dbl room with a very high ceilin...
# 9  3 Bed House with garden close to Thames river ...
#
#                                                space  \
# 0  Amenities Bedding: 1 Double bed, 1 living room...
# 1  Hello Everyone, I'm offering my lovely double ...
# 2  Bright Chelsea Apartment  This is a bright one...
# 3  This is a wonderful very popular beautiful, sp...
# 4  Enjoy a boutique London townhouse bed and brea...
# 5  10 mins walk to Southfields tube and Wimbledon...
# 6  Big double Room to let up to 6 months or more....
# 7  This is a spacious Bedsit + En-Suite at the to...
# 8  **** PLEASE MESSAGE & CHAT TO ME FIRST **** an...
# 9  Residential neighborhood, mix of English and c...
#
#                                          description experiences_offered  \
# 0  Unlike most rental apartments out there my fla...              family
# 1  My bright double bedroom with a large window h...            business
# 2  Lots of windows and light.  St Luke's Gardens ...            romantic
# 3  You'll have a wonderful stay in this superb mo...                none
# 4  Enjoy a chic stay in this elegant but fully mo...            business
# 5  Large, all comforts, 2-bed flat; first floor; ...                none
# 6  Big room with double bed/ clean sheets/ clean ...                none
# 7  Walking distance to Twickenham Stadium, 35 min...                none
# 8  Bright, large dbl room with a very high ceilin...                none
# 9  3 Bed House with garden close to Thames river ...                none
#
#                                neighborhood_overview  \
# 0  Not even 10 minutes by metro from Victoria Sta...
# 1  Finsbury Park is a friendly melting pot commun...
# 2                                     It is Chelsea.
# 3  Location, location, location! You won't find b...
# 4  Fulham is 'villagey' and residential – a real ...
# 5  This is a leafy residential area with excellen...
# 6  Barnet is one of the largest boroughs in Londo...
# 7                             Peaceful and friendly.
# 8                                                NaN
# 9  Residential family neighborhood, with both Eng...
#
#                                                notes  \
# 0  No Smoking (very strict) Check-in time is afte...
# 1  For art lovers I can give guest my Tate Member...
# 2  The building next door is in the process of be...
# 3  This property has new flooring throughout. Gue...
# 4                           Ask us and we'll answer.
# 5                         Non-smokers only. No pets.
# 6                  Please read rules book on arrival
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                              transit  \
# 0  Tons of buses (24hrs) go into central London f...
# 1  The flat only a 10 minute walk to Finsbury Par...
# 2  The underground stations are South Kensington ...
# 3  You can walk to tourist London or take numerou...
# 4  The Tube is just 2 minutes away, or take a sho...
# 5  Free off-street parking; buses to Richmond/Too...
# 6  Brent Cross station 7 minutes away Heathrow is...
# 7                        Buses, trains, underground.
# 8                                                NaN
# 9  7 min walk from the 'Kew Gardens' District lin...
#
#                                               access  \
# 0     Guest will have access to the entire apartment
# 1  Guest will have access to the self catering ki...
# 2  There are two wardrobes for guests exclusive u...
# 3            Full use of whole independent apartment
# 4  We give you a set of keys to use during your s...
# 5              Entire flat; use of communal gardens.
# 6  Fully equipped kitchen/ upstairs bathroom/ dow...
# 7                      Shared front door and stairs.
# 8                                                NaN
# 9                             Whole house and garden
#
#                                          interaction  \
# 0  No interaction with guests as you book the ent...
# 1  I like to have little chats with my guest over...
# 2  If I am in the country I like to welcome my gu...
# 3  Always available by email or phone (before, du...
# 4  When you need us, we are here. Consider us you...
# 5  I'm happy to provide you with any helpful hint...
# 6                                              daily
# 7  Quite hands off, as this is quite a self-conta...
# 8                                                NaN
# 9                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  No Smoking (very strict) No pets are allowed i...            NaN
# 1  I'm an artist and have my artwork up on the wa...            NaN
# 2  NO SMOKING PLEASE.. No unauthorised guests. No...            NaN
# 3  * The apartment benefits from new flooring thr...            NaN
# 4  Guests respect our high standards and we respe...            NaN
# 5  No smoking. No parties. No loud music after 10...            NaN
# 6  Guests can use the kitchen at any time as long...            NaN
# 7  - No smoking. No shoes  upstairs. - No shoes, ...            NaN
# 8  I would just politely ask all potential guests...            NaN
# 9  - non-smoking,  - pets after agreement,  - no ...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/1d720898-c...
# 1         NaN  https://a0.muscache.com/im/pictures/ffb507b7-9...
# 2         NaN  https://a0.muscache.com/im/pictures/428392/462...
# 3         NaN  https://a0.muscache.com/im/pictures/39d5309d-f...
# 4         NaN  https://a0.muscache.com/im/pictures/11901327/e...
# 5         NaN  https://a0.muscache.com/im/pictures/d693d930-0...
# 6         NaN  https://a0.muscache.com/im/pictures/456905/a00...
# 7         NaN  https://a0.muscache.com/im/pictures/f78bf957-0...
# 8         NaN  https://a0.muscache.com/im/pictures/2e0aab5c-3...
# 9         NaN  https://a0.muscache.com/im/pictures/457052/6e8...
#
#    xl_picture_url  host_id                                  host_url  \
# 0             NaN    43039   https://www.airbnb.com/users/show/43039
# 1             NaN    54730   https://www.airbnb.com/users/show/54730
# 2             NaN    60302   https://www.airbnb.com/users/show/60302
# 3             NaN    67564   https://www.airbnb.com/users/show/67564
# 4             NaN    67915   https://www.airbnb.com/users/show/67915
# 5             NaN   102813  https://www.airbnb.com/users/show/102813
# 6             NaN   103583  https://www.airbnb.com/users/show/103583
# 7             NaN   144444  https://www.airbnb.com/users/show/144444
# 8             NaN   150078  https://www.airbnb.com/users/show/150078
# 9             NaN   155938  https://www.airbnb.com/users/show/155938
#
#    host_name  host_since                        host_location  \
# 0    Adriano  2009-10-03      London, England, United Kingdom
# 1      Alina  2009-11-16      London, England, United Kingdom
# 2   Philippa  2009-12-05  Kensington, England, United Kingdom
# 3        Liz  2010-01-04      London, England, United Kingdom
# 4  Charlotte  2010-01-05      London, England, United Kingdom
# 5     Amanda  2010-04-03                   Rome, Lazio, Italy
# 6      Grace  2010-04-05      London, England, United Kingdom
# 7    Chi-Chi  2010-06-14   Isleworth, England, United Kingdom
# 8    Michael  2010-06-22      London, England, United Kingdom
# 9      Geert  2010-06-30    Richmond, England, United Kingdom
#
#                                           host_about  host_response_time  \
# 0  Hello, I'm a friendly Italian man with a very ...      within an hour
# 1  I am a Multi-Media Visual Artist and Creative ...  within a few hours
# 2  English, grandmother,  I have travelled quite ...        within a day
# 3  We are Liz and Jack.  We manage a number of ho...      within an hour
# 4  Named best B&B by The Times. Easy going hosts,...      within an hour
# 5  Hi, I'm a sociologist/anthropologist, NLP exec...  within a few hours
# 6  Easy going, friendly\n\nAttentive to detail an...      within an hour
# 7  Quite busy and often in a different place ever...  within a few hours
# 8  Friendly easy going guy with varied interests....  within a few hours
# 9                                                  .  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                 100%                 t
# 1                63%                  86%                 f
# 2                57%                  67%                 f
# 3               100%                  93%                 f
# 4               100%                  NaN                 f
# 5               100%                  93%                 t
# 6               100%                 100%                 t
# 7               100%                  90%                 f
# 8               100%                  33%                 f
# 9               100%                  81%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/47773...
# 1  https://a0.muscache.com/im/users/54730/profile...
# 2  https://a0.muscache.com/im/users/60302/profile...
# 3  https://a0.muscache.com/im/users/67564/profile...
# 4  https://a0.muscache.com/im/users/67915/profile...
# 5  https://a0.muscache.com/im/pictures/user/2e886...
# 6  https://a0.muscache.com/im/users/103583/profil...
# 7  https://a0.muscache.com/im/pictures/user/8028d...
# 8  https://a0.muscache.com/im/users/150078/profil...
# 9  https://a0.muscache.com/im/users/155938/profil...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/47773...
# 1  https://a0.muscache.com/im/users/54730/profile...
# 2  https://a0.muscache.com/im/users/60302/profile...
# 3  https://a0.muscache.com/im/users/67564/profile...
# 4  https://a0.muscache.com/im/users/67915/profile...
# 5  https://a0.muscache.com/im/pictures/user/2e886...
# 6  https://a0.muscache.com/im/users/103583/profil...
# 7  https://a0.muscache.com/im/pictures/user/8028d...
# 8  https://a0.muscache.com/im/users/150078/profil...
# 9  https://a0.muscache.com/im/users/155938/profil...
#
#            host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0                     Brixton                  3.0                        3.0
# 1             LB of Islington                  4.0                        4.0
# 2                     Chelsea                  1.0                        1.0
# 3                   Fitzrovia                 18.0                       18.0
# 4                      Fulham                  3.0                        3.0
# 5                   Wimbledon                  1.0                        1.0
# 6                LB of Barnet                  3.0                        3.0
# 7              LB of Hounslow                  2.0                        2.0
# 8                  Bloomsbury                  0.0                        0.0
# 9  LB of Richmond upon Thames                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'facebook', 'reviews', 'off...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 4  ['email', 'phone', 'jumio', 'selfie', 'governm...                    t
# 5  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 6  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 7  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 8                      ['email', 'phone', 'reviews']                    t
# 9  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#   host_identity_verified                                       street  \
# 0                      t                       London, United Kingdom
# 1                      t    Islington, Greater London, United Kingdom
# 2                      t                       London, United Kingdom
# 3                      t            London, Fitzrovia, United Kingdom
# 4                      f                       London, United Kingdom
# 5                      f            Wimbledon, London, United Kingdom
# 6                      f              Barnet, England, United Kingdom
# 7                      t          Twickenham, England, United Kingdom
# 8                      f  Camden Town, Greater London, United Kingdom
# 9                      t     Richmond, United Kingdom, United Kingdom
#
#                   neighbourhood  neighbourhood_cleansed  \
# 0                       Brixton                 Lambeth
# 1               LB of Islington               Islington
# 2  RB of Kensington and Chelsea  Kensington and Chelsea
# 3                     Fitzrovia             Westminster
# 4    LB of Hammersmith & Fulham  Hammersmith and Fulham
# 5              LB of Wandsworth              Wandsworth
# 6                  LB of Barnet                  Barnet
# 7                LB of Hounslow                Hounslow
# 8                   St. Pancras                  Camden
# 9    LB of Richmond upon Thames    Richmond upon Thames
#
#    neighbourhood_group_cleansed         city           state   zipcode  \
# 0                           NaN       London             NaN   SW9 8DG
# 1                           NaN    Islington  Greater London      N4 3
# 2                           NaN       London             NaN       SW3
# 3                           NaN       London       Fitzrovia    W1T4BP
# 4                           NaN       London             NaN   SW6 1EJ
# 5                           NaN    Wimbledon          London  SW19 6QH
# 6                           NaN       Barnet         England    NW11 9
# 7                           NaN   Twickenham         England   TW7 7HG
# 8                           NaN  Camden Town  Greater London    WC1N 1
# 9                           NaN     Richmond  United Kingdom     TW9 4
#
#    market               smart_location country_code         country  latitude  \
# 0  London       London, United Kingdom           GB  United Kingdom  51.46225
# 1  London    Islington, United Kingdom           GB  United Kingdom  51.56802
# 2  London       London, United Kingdom           GB  United Kingdom  51.48796
# 3  London       London, United Kingdom           GB  United Kingdom  51.52195
# 4  London       London, United Kingdom           GB  United Kingdom  51.47935
# 5  London    Wimbledon, United Kingdom           GB  United Kingdom  51.44687
# 6  London       Barnet, United Kingdom           GB  United Kingdom  51.57224
# 7  London   Twickenham, United Kingdom           GB  United Kingdom  51.46507
# 8  London  Camden Town, United Kingdom           GB  United Kingdom  51.52513
# 9  London     Richmond, United Kingdom           GB  United Kingdom  51.47934
#
#    longitude is_location_exact      property_type        room_type  \
# 0   -0.11732                 t          Apartment  Entire home/apt
# 1   -0.11121                 t          Apartment     Private room
# 2   -0.16898                 t          Apartment  Entire home/apt
# 3   -0.14094                 t          Apartment  Entire home/apt
# 4   -0.19743                 t  Bed and breakfast     Private room
# 5   -0.21874                 t          Apartment  Entire home/apt
# 6   -0.20906                 t              House     Private room
# 7   -0.32421                 t              House     Private room
# 8   -0.11749                 t          Apartment     Private room
# 9   -0.28066                 t          Townhouse  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             4        1.0       1.0   1.0  Real Bed
# 1             2        1.0       1.0   0.0  Real Bed
# 2             2        1.0       1.0   1.0  Real Bed
# 3             6        2.0       3.0   3.0  Real Bed
# 4             2        1.0       1.0   1.0  Real Bed
# 5             4        1.0       2.0   2.0  Real Bed
# 6             2        1.5       1.0   0.0  Real Bed
# 7             2        1.0       1.0   1.0  Real Bed
# 8             4        1.0       1.0   2.0  Real Bed
# 9             5        1.5       3.0   3.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN   $88.00
# 1  {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...        538.0   $65.00
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $100.00
# 3  {TV,Wifi,Kitchen,"Paid parking off premises",E...          NaN  $300.00
# 4  {TV,Internet,Wifi,"Air conditioning",Breakfast...          NaN  $150.00
# 5  {TV,Wifi,Kitchen,"Free parking on premises",El...        700.0   $65.00
# 6  {Wifi,Kitchen,"Free street parking","Buzzer/wi...          NaN   $29.00
# 7  {Wifi,Kitchen,"Pets live on this property",Cat...          NaN  $100.00
# 8  {Internet,Wifi,Kitchen,Breakfast,"Buzzer/wirel...          NaN   $45.00
# 9  {TV,Internet,Wifi,Kitchen,Heating,"Family/kid ...          NaN  $195.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $645.00     $2,350.00          $400.00       $30.00                2
# 1      $333.00     $1,176.00          $100.00       $15.00                1
# 2      $600.00     $2,250.00          $150.00       $50.00                2
# 3    $1,378.00           NaN          $350.00       $70.00                3
# 4          NaN           NaN              NaN          NaN                1
# 5      $630.00     $2,515.00          $250.00       $50.00                2
# 6      $195.00       $795.00          $100.00        $0.00                1
# 7          NaN           NaN              NaN          NaN                1
# 8          NaN           NaN              NaN          NaN                1
# 9          NaN           NaN              NaN          NaN                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $20.00               2             180                       2
# 1       $15.00               1              29                       1
# 2        $0.00              10              50                      10
# 3       $10.00               3             365                       3
# 4        $0.00               3              21                       2
# 5       $11.00              21            1125                      11
# 6        $8.00              10            1120                      10
# 7        $0.00               1              21                       1
# 8       $20.00              14             365                      14
# 9        $0.00               3              22                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     180                     180
# 1                       1                      29                      29
# 2                      10                      50                      50
# 3                       3                     365                     365
# 4                       3                      21                      21
# 5                      21                    1125                    1125
# 6                      10                    1120                    1120
# 7                       1                      21                      21
# 8                      14                     365                     365
# 9                       3                      22                      22
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                   180.0       5 days ago
# 1                     1.0                    29.0    10 months ago
# 2                    10.0                    50.0      6 weeks ago
# 3                     3.0                   365.0       2 days ago
# 4                     3.0                    21.0    37 months ago
# 5                    20.4                  1125.0       a week ago
# 6                    10.0                  1120.0      3 weeks ago
# 7                     1.0                    21.0     2 months ago
# 8                    14.0                   365.0     2 months ago
# 9                     3.0                    22.0      2 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               26               42               72
# 1                t               24               54               84
# 2                t                9               15               16
# 3                t               17               21               33
# 4                t               29               59               89
# 5                t                1               10               40
# 6                t                0               15               31
# 7                t               30               60               90
# 8                t               12               42               72
# 9                t               26               30               46
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               332            2020-02-16                188
# 1               356            2020-02-16                 20
# 2               185            2020-02-16                 88
# 3               230            2020-02-16                 42
# 4               364            2020-02-16                  0
# 5                91            2020-02-17                 34
# 6               277            2020-02-17                127
# 7               362            2020-02-17                  5
# 8               162            2020-02-16                191
# 9               287            2020-02-17                 77
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      5   2010-03-21  2020-01-24                  92.0
# 1                      6   2010-08-18  2019-11-25                  97.0
# 2                      7   2009-12-21  2019-09-23                  96.0
# 3                      3   2011-03-21  2019-11-02                  94.0
# 4                      0          NaN         NaN                   NaN
# 5                      8   2016-03-05  2019-09-15                  93.0
# 6                      9   2010-04-14  2020-01-04                  95.0
# 7                      1   2010-10-16  2019-05-26                  88.0
# 8                     15   2010-07-17  2019-12-24                  93.0
# 9                     13   2010-10-25  2019-10-30                  97.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                        9.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                        9.0                    9.0
# 4                     NaN                        NaN                    NaN
# 5                    10.0                       10.0                    9.0
# 6                    10.0                       10.0                   10.0
# 7                     9.0                       10.0                   10.0
# 8                    10.0                        9.0                   10.0
# 9                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                  9.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                    10.0                  9.0
# 3                          9.0                    10.0                  9.0
# 4                          NaN                     NaN                  NaN
# 5                         10.0                     9.0                  9.0
# 6                         10.0                     9.0                 10.0
# 7                         10.0                    10.0                  8.0
# 8                         10.0                    10.0                  9.0
# 9                         10.0                    10.0                  9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                t
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                t
# 3                f     NaN                NaN                t
# 4                f     NaN                NaN                f
# 5                f     NaN                NaN                t
# 6                f     NaN                NaN                t
# 7                f     NaN                NaN                f
# 8                f     NaN                NaN                f
# 9                f     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
# 5                        f                     moderate
# 6                        f  strict_14_with_grace_period
# 7                        f                     flexible
# 8                        f  strict_14_with_grace_period
# 9                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                t
# 1                             f                                f
# 2                             t                                t
# 3                             f                                f
# 4                             f                                f
# 5                             f                                f
# 6                             f                                f
# 7                             f                                f
# 8                             f                                f
# 9                             f                                f
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               2
# 2                               1
# 3                              15
# 4                               2
# 5                               1
# 6                               3
# 7                               2
# 8                               1
# 9                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            1
# 3                                           15
# 4                                            0
# 5                                            1
# 6                                            0
# 7                                            1
# 8                                            0
# 9                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             2
# 5                                             0
# 6                                             3
# 7                                             1
# 8                                             1
# 9                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.56
# 1                                            0               0.17
# 2                                            0               0.71
# 3                                            0               0.39
# 4                                            0                NaN
# 5                                            0               0.71
# 6                                            0               1.06
# 7                                            0               0.04
# 8                                            0               1.64
# 9                                            0               0.68

# %%
df_listings_details.shape
# Out:
# (87571, 106)

# %% [markdown]
# # 2) Exploratory analysis
#
# To understand the data and a get a sense of what we are working with

# %%
df_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df_listings.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df_listings_details.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %% [markdown]
# Based on reference notebook, as well as inspecting the full listings sheet, we can consider bringing these columns in to our main listings sheet.

# %%
cols_to_pull = ["id","property_type", "accommodates", "first_review", "review_scores_value", 
                "review_scores_cleanliness", "review_scores_location", "review_scores_accuracy", 
                "review_scores_communication", "review_scores_checkin", "review_scores_rating", 
                "maximum_nights", "listing_url", 
                "host_is_superhost", "host_about", "host_response_time", "host_response_rate", 
                "street", "price", "weekly_price", "monthly_price", "market",
                "host_identity_verified","neighbourhood_cleansed", "bathrooms", "bedrooms", "beds", "bed_type",
                "experiences_offered","notes","neighborhood_overview", "amenities", "cleaning_fee",
                "cancellation_policy",
               ]

df_listings = pd.merge(df_listings, df_listings_details[cols_to_pull], left_on='id', right_on='id', how='left')
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87571 entries, 0 to 87570
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              87571 non-null  int64
#  1   name                            87546 non-null  object
#  2   host_id                         87571 non-null  int64
#  3   host_name                       87557 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   87571 non-null  object
#  6   latitude                        87571 non-null  float64
#  7   longitude                       87571 non-null  float64
#  8   room_type                       87571 non-null  object
#  9   price_x                         87571 non-null  int64
#  10  minimum_nights                  87571 non-null  int64
#  11  number_of_reviews               87571 non-null  int64
#  12  last_review                     66920 non-null  object
#  13  reviews_per_month               66920 non-null  float64
#  14  calculated_host_listings_count  87571 non-null  int64
#  15  availability_365                87571 non-null  int64
#  16  property_type                   87571 non-null  object
#  17  accommodates                    87571 non-null  int64
#  18  first_review                    66920 non-null  object
#  19  review_scores_value             65164 non-null  float64
#  20  review_scores_cleanliness       65222 non-null  float64
#  21  review_scores_location          65164 non-null  float64
#  22  review_scores_accuracy          65211 non-null  float64
#  23  review_scores_communication     65217 non-null  float64
#  24  review_scores_checkin           65163 non-null  float64
#  25  review_scores_rating            65268 non-null  float64
#  26  maximum_nights                  87571 non-null  int64
#  27  listing_url                     87571 non-null  object
#  28  host_is_superhost               87557 non-null  object
#  29  host_about                      50644 non-null  object
#  30  host_response_time              59242 non-null  object
#  31  host_response_rate              59242 non-null  object
#  32  street                          87571 non-null  object
#  33  price_y                         87571 non-null  object
#  34  weekly_price                    6717 non-null   object
#  35  monthly_price                   4780 non-null   object
#  36  market                          86823 non-null  object
#  37  host_identity_verified          87557 non-null  object
#  38  neighbourhood_cleansed          87571 non-null  object
#  39  bathrooms                       87447 non-null  float64
#  40  bedrooms                        87458 non-null  float64
#  41  beds                            86867 non-null  float64
#  42  bed_type                        87571 non-null  object
#  43  experiences_offered             87571 non-null  object
#  44  notes                           33602 non-null  object
#  45  neighborhood_overview           56387 non-null  object
#  46  amenities                       87571 non-null  object
#  47  cleaning_fee                    66100 non-null  object
#  48  cancellation_policy             87571 non-null  object
# dtypes: float64(14), int64(9), object(26)
# memory usage: 33.4+ MB

# %%
del df_listings_details

# %%
df_listings.isnull().sum()
# Out:
# id                                    0
# name                                 25
# host_id                               0
# host_name                            14
# neighbourhood_group               87571
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price_x                               0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       20651
# reviews_per_month                 20651
# calculated_host_listings_count        0
# availability_365                      0
# property_type                         0
# accommodates                          0
# first_review                      20651
# review_scores_value               22407
# review_scores_cleanliness         22349
# review_scores_location            22407
# review_scores_accuracy            22360
# review_scores_communication       22354
# review_scores_checkin             22408
# review_scores_rating              22303
# maximum_nights                        0
# listing_url                           0
# host_is_superhost                    14
# host_about                        36927
# host_response_time                28329
# host_response_rate                28329
# street                                0
# price_y                               0
# weekly_price                      80854
# monthly_price                     82791
# market                              748
# host_identity_verified               14
# neighbourhood_cleansed                0
# bathrooms                           124
# bedrooms                            113
# beds                                704
# bed_type                              0
# experiences_offered                   0
# notes                             53969
# neighborhood_overview             31184
# amenities                             0
# cleaning_fee                      21471
# cancellation_policy                   0
# dtype: int64

# %% [markdown]
# From the above, weekly_price and monthly_price are mainly missing. We can drop these. We will also drop neighbourhood_group because it seems to be entirely missing.

# %%
df_listings.drop(['weekly_price','monthly_price','neighbourhood_group'],axis=1,inplace=True)

# %%
df_listings[df_listings["neighbourhood"]!=df_listings["neighbourhood_cleansed"]]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price_x, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, property_type, accommodates, first_review, review_scores_value, review_scores_cleanliness, review_scores_location, review_scores_accuracy, review_scores_communication, review_scores_checkin, review_scores_rating, maximum_nights, listing_url, host_is_superhost, host_about, host_response_time, host_response_rate, street, price_y, market, host_identity_verified, neighbourhood_cleansed, bathrooms, bedrooms, beds, bed_type, experiences_offered, notes, neighborhood_overview, amenities, cleaning_fee, cancellation_policy]
# Index: []

# %% [markdown]
# We also see that "neighbourhood" is the same as "neighbourhood_cleansed". Let's drop neighbourhood_cleansed.

# %%
df_listings.drop(['neighbourhood_cleansed'],axis=1,inplace=True)

# %%
df_listings[["price_x","price_y"]]
# Out:
#        price_x  price_y
# 0           88   $88.00
# 1           65   $65.00
# 2          100  $100.00
# 3          300  $300.00
# 4          150  $150.00
# ...        ...      ...
# 87566      180  $180.00
# 87567      400  $400.00
# 87568       30   $30.00
# 87569      400  $400.00
# 87570      120  $120.00
#
# [87571 rows x 2 columns]

# %%
df_listings["price_y"] = df_listings["price_y"].str.replace(",","")
df_listings["price_y"] = df_listings["price_y"].str.replace("$","")
df_listings["price_y"] = df_listings["price_y"].astype(float)

# %%
df_listings[df_listings["price_x"]!=df_listings["price_y"]]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price_x, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, property_type, accommodates, first_review, review_scores_value, review_scores_cleanliness, review_scores_location, review_scores_accuracy, review_scores_communication, review_scores_checkin, review_scores_rating, maximum_nights, listing_url, host_is_superhost, host_about, host_response_time, host_response_rate, street, price_y, market, host_identity_verified, bathrooms, bedrooms, beds, bed_type, experiences_offered, notes, neighborhood_overview, amenities, cleaning_fee, cancellation_policy]
# Index: []

# %% [markdown]
# From the above, we can conclude the that price in the listing details list is weekly to the price in the trimmed listings list. We can also assume cleaning fees is over and above price.

# %%
df_listings.drop(["price_y"],axis=1,inplace=True)

# %%
df_listings = df_listings.rename(columns={"price_x":"price_per_night"})

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87571 entries, 0 to 87570
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              87571 non-null  int64
#  1   name                            87546 non-null  object
#  2   host_id                         87571 non-null  int64
#  3   host_name                       87557 non-null  object
#  4   neighbourhood                   87571 non-null  object
#  5   latitude                        87571 non-null  float64
#  6   longitude                       87571 non-null  float64
#  7   room_type                       87571 non-null  object
#  8   price_per_night                 87571 non-null  int64
#  9   minimum_nights                  87571 non-null  int64
#  10  number_of_reviews               87571 non-null  int64
#  11  last_review                     66920 non-null  object
#  12  reviews_per_month               66920 non-null  float64
#  13  calculated_host_listings_count  87571 non-null  int64
#  14  availability_365                87571 non-null  int64
#  15  property_type                   87571 non-null  object
#  16  accommodates                    87571 non-null  int64
#  17  first_review                    66920 non-null  object
#  18  review_scores_value             65164 non-null  float64
#  19  review_scores_cleanliness       65222 non-null  float64
#  20  review_scores_location          65164 non-null  float64
#  21  review_scores_accuracy          65211 non-null  float64
#  22  review_scores_communication     65217 non-null  float64
#  23  review_scores_checkin           65163 non-null  float64
#  24  review_scores_rating            65268 non-null  float64
#  25  maximum_nights                  87571 non-null  int64
#  26  listing_url                     87571 non-null  object
#  27  host_is_superhost               87557 non-null  object
#  28  host_about                      50644 non-null  object
#  29  host_response_time              59242 non-null  object
#  30  host_response_rate              59242 non-null  object
#  31  street                          87571 non-null  object
#  32  market                          86823 non-null  object
#  33  host_identity_verified          87557 non-null  object
#  34  bathrooms                       87447 non-null  float64
#  35  bedrooms                        87458 non-null  float64
#  36  beds                            86867 non-null  float64
#  37  bed_type                        87571 non-null  object
#  38  experiences_offered             87571 non-null  object
#  39  notes                           33602 non-null  object
#  40  neighborhood_overview           56387 non-null  object
#  41  amenities                       87571 non-null  object
#  42  cleaning_fee                    66100 non-null  object
#  43  cancellation_policy             87571 non-null  object
# dtypes: float64(13), int64(9), object(22)
# memory usage: 30.1+ MB
